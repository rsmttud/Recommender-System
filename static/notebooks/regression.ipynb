# %% [markdown]
# # Problem Statement Analysis
#
# <p>The notebook aims to give an descriptve overview about the problem described below. It should be understood as an example notebook and not to solve the problem in detail.
# Please take this notebook and advice you with your Data Scientist or Machine Learning expert to give him first insight about the corresponding domain and the problem statement.
# In addition, this jupyter notebook serves you as an summary for your given analysis. </p>

# %% [markdown]
# ## Some Details about your Analysis

# %% [markdown]
# __Recommended Machine Learning Approach__: regression <hr>

# %% [markdown]
# __Short Description__: Hello my name is daniel. Hello my name is daniel.  <hr>

# %% [markdown]
# __Long Description__: Hello my name is daniel. Hello my name is daniel.  <hr>

# %% [markdown]
# ### Potential Extracted Data Entities

# %% [markdown]
# <ul><li>name</li><li>Hello</li></ul>

# %% [markdown]
# ### Regression Analysis (Linear Regression)

# %%
import numpy as np
import pandas as pd 
import sklearn
import matplotlib.pyplot as plt

# %%
var_entity_1 = "name"

# %%
var_entity_2 = "Hello"

# %%
# %matplotlib inline
from sklearn import datasets
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
import matplotlib.pyplot as plt

lr = linear_model.LinearRegression()
boston = datasets.load_boston()
y = boston.target

# cross_val_predict returns an array of the same size as `y` where each entry
# is a prediction obtained by cross validation:
predicted = cross_val_predict(lr, boston.data, y, cv=10)

plt.figure(figsize = (15,10))
plt.scatter(y, predicted, c = "#00535a", alpha = 0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4, c= "#b4126b")
plt.xlabel('Entity X')
plt.ylabel('Entity Y')
plt.show()
