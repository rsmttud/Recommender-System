# %% [markdown]
# # DAN Extrinsic Evaluation (I)
# ## Creating possible DAN Combinations

# %%
import sys
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import time
sys.path.append(os.path.abspath("../"))
from rs_helper import DAN

# %% [markdown]
# ## Reading Data

# %%
data_dir = "../datasets/final_datasets/clean_dataset"

# %%
def read_data(_dir:str) -> pd.DataFrame:
    data = {}
    #data["url"] = []
    data["text"] = []
    data["class"] = []
    for root, dirs, files in os.walk(_dir):
        for _dir in dirs: 
            for txt_file in [x for x in os.listdir(os.path.join(root, _dir)) if x.endswith((".txt", ".TXT"))]:
                # Class name = dir name
                class_name = _dir
                #Read File
                file_name = os.path.abspath(os.path.join(root, _dir, txt_file))
                file = open(file_name, "r")
                txt = file.read()
                file.close()
                #data["url"].append(file_name)
                data["text"].append(txt)
                data["class"].append(class_name)
    df = pd.DataFrame.from_dict(data)
    del data
    return df

# %%
df = read_data(data_dir).sample(frac=1)

# %%
df.head()
# Out:
#                                                    text       class
# 4786  introduction clustering is an unsupervised lea...  clustering
# 5278  clustering problem clustering is a distributio...  clustering
# 1897  thus the model is extrapolated and the outlier...  prediction
# 4325  clustering is a popular approach to study the ...  clustering
# 723   thus crossdomain sentiment classification is p...  prediction

# %% [markdown]
# ## FastText Model

# %%
from rs_helper import FastText
import itertools

# %%
ft_model = FastText()
# Out:
# INFO:tensorflow:FastText Model is loading
# INFO:tensorflow:FastText Model is loading
# INFO:tensorflow:FastText Model loaded!
# INFO:tensorflow:FastText Model loaded!

# %%
combinations = {"num_layer": np.arange(2,8), "classifier_shape": [[200],[100,50], [200,100]], "epoches":[5,10,20], "drop_prob":[0.2,0.3,0.5]}

# %%
combinations = list(itertools.product(combinations["num_layer"], combinations["classifier_shape"], combinations["epoches"], combinations["drop_prob"]))

# %%
len(combinations)
# Out:
# 162

# %%
# Still missing combinations
#combinations[45:]

# %%
# %%time
tf.logging.set_verbosity(tf.logging.ERROR)
for i,x in enumerate(combinations[51:]):
    i+=51
    t1 = time.time()
    tf.reset_default_graph()
    model_dir = os.path.join("DAN_COMBINATIONS", "model_layer{}".format(i))
    _DAN = DAN(ft_model)
    _DAN.train(text=df["text"].tolist(),
               labels=df["class"].tolist(),
               save_path = model_dir,
               model_name = "DAN_{}".format(i),
               epoches = x[2],
               num_hidden_layer = x[0],
               wdrop_prob = x[3],
               classifier_shape = x[1]
              )
    t2 = time.time()
    _DAN.save_config_json(os.path.join(model_dir, "config.json"), time=(t2-t1)/60)
    print("Model_{} trained and saved to {}".format(i, model_dir))
# Out:
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer51.
# Model_51 trained and saved to DAN_COMBINATIONS/model_layer51
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer52.
# Model_52 trained and saved to DAN_COMBINATIONS/model_layer52
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer53.
# Model_53 trained and saved to DAN_COMBINATIONS/model_layer53
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer54.
# Model_54 trained and saved to DAN_COMBINATIONS/model_layer54
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer55.
# Model_55 trained and saved to DAN_COMBINATIONS/model_layer55
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer56.
# Model_56 trained and saved to DAN_COMBINATIONS/model_layer56
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer57.
# Model_57 trained and saved to DAN_COMBINATIONS/model_layer57
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer58.
# Model_58 trained and saved to DAN_COMBINATIONS/model_layer58
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer59.
# Model_59 trained and saved to DAN_COMBINATIONS/model_layer59
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer60.
# Model_60 trained and saved to DAN_COMBINATIONS/model_layer60
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer61.
# Model_61 trained and saved to DAN_COMBINATIONS/model_layer61
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer62.
# Model_62 trained and saved to DAN_COMBINATIONS/model_layer62
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer63.
# Model_63 trained and saved to DAN_COMBINATIONS/model_layer63
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer64.
# Model_64 trained and saved to DAN_COMBINATIONS/model_layer64
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer65.
# Model_65 trained and saved to DAN_COMBINATIONS/model_layer65
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer66.
# Model_66 trained and saved to DAN_COMBINATIONS/model_layer66
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer67.
# Model_67 trained and saved to DAN_COMBINATIONS/model_layer67
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer68.
# Model_68 trained and saved to DAN_COMBINATIONS/model_layer68
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer69.
# Model_69 trained and saved to DAN_COMBINATIONS/model_layer69
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer70.
# Model_70 trained and saved to DAN_COMBINATIONS/model_layer70
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer71.
# Model_71 trained and saved to DAN_COMBINATIONS/model_layer71
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer72.
# Model_72 trained and saved to DAN_COMBINATIONS/model_layer72
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer73.
# Model_73 trained and saved to DAN_COMBINATIONS/model_layer73
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer74.
# Model_74 trained and saved to DAN_COMBINATIONS/model_layer74
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer75.
# Model_75 trained and saved to DAN_COMBINATIONS/model_layer75
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer76.
# Model_76 trained and saved to DAN_COMBINATIONS/model_layer76
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer77.
# Model_77 trained and saved to DAN_COMBINATIONS/model_layer77
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer78.
# Model_78 trained and saved to DAN_COMBINATIONS/model_layer78
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer79.
# Model_79 trained and saved to DAN_COMBINATIONS/model_layer79
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer80.
# Model_80 trained and saved to DAN_COMBINATIONS/model_layer80
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer81.
# Model_81 trained and saved to DAN_COMBINATIONS/model_layer81
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer82.
# Model_82 trained and saved to DAN_COMBINATIONS/model_layer82
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer83.
# Model_83 trained and saved to DAN_COMBINATIONS/model_layer83
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer84.
# Model_84 trained and saved to DAN_COMBINATIONS/model_layer84
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer85.
# Model_85 trained and saved to DAN_COMBINATIONS/model_layer85
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer86.
# Model_86 trained and saved to DAN_COMBINATIONS/model_layer86
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer87.
# Model_87 trained and saved to DAN_COMBINATIONS/model_layer87
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer88.
# Model_88 trained and saved to DAN_COMBINATIONS/model_layer88
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer89.
# Model_89 trained and saved to DAN_COMBINATIONS/model_layer89
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer90.
# Model_90 trained and saved to DAN_COMBINATIONS/model_layer90
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer91.
# Model_91 trained and saved to DAN_COMBINATIONS/model_layer91
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer92.
# Model_92 trained and saved to DAN_COMBINATIONS/model_layer92
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer93.
# Model_93 trained and saved to DAN_COMBINATIONS/model_layer93
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer94.
# Model_94 trained and saved to DAN_COMBINATIONS/model_layer94
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer95.
# Model_95 trained and saved to DAN_COMBINATIONS/model_layer95
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer96.
# Model_96 trained and saved to DAN_COMBINATIONS/model_layer96
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer97.
# Model_97 trained and saved to DAN_COMBINATIONS/model_layer97
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer98.
# Model_98 trained and saved to DAN_COMBINATIONS/model_layer98
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer99.
# Model_99 trained and saved to DAN_COMBINATIONS/model_layer99
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer100.
# Model_100 trained and saved to DAN_COMBINATIONS/model_layer100
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer101.
# Model_101 trained and saved to DAN_COMBINATIONS/model_layer101
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer102.
# Model_102 trained and saved to DAN_COMBINATIONS/model_layer102
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer103.
# Model_103 trained and saved to DAN_COMBINATIONS/model_layer103
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer104.
# Model_104 trained and saved to DAN_COMBINATIONS/model_layer104
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer105.
# Model_105 trained and saved to DAN_COMBINATIONS/model_layer105
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer106.
# Model_106 trained and saved to DAN_COMBINATIONS/model_layer106
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer107.
# Model_107 trained and saved to DAN_COMBINATIONS/model_layer107
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer108.
# Model_108 trained and saved to DAN_COMBINATIONS/model_layer108
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer109.
# Model_109 trained and saved to DAN_COMBINATIONS/model_layer109
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer110.
# Model_110 trained and saved to DAN_COMBINATIONS/model_layer110
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer111.
# Model_111 trained and saved to DAN_COMBINATIONS/model_layer111
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer112.
# Model_112 trained and saved to DAN_COMBINATIONS/model_layer112
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer113.
# Model_113 trained and saved to DAN_COMBINATIONS/model_layer113
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer114.
# Model_114 trained and saved to DAN_COMBINATIONS/model_layer114
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer115.
# Model_115 trained and saved to DAN_COMBINATIONS/model_layer115
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer116.
# Model_116 trained and saved to DAN_COMBINATIONS/model_layer116
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer117.
# Model_117 trained and saved to DAN_COMBINATIONS/model_layer117
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer118.
# Model_118 trained and saved to DAN_COMBINATIONS/model_layer118
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer119.
# Model_119 trained and saved to DAN_COMBINATIONS/model_layer119
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer120.
# Model_120 trained and saved to DAN_COMBINATIONS/model_layer120
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer121.
# Model_121 trained and saved to DAN_COMBINATIONS/model_layer121
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer122.
# Model_122 trained and saved to DAN_COMBINATIONS/model_layer122
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer123.
# Model_123 trained and saved to DAN_COMBINATIONS/model_layer123
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer124.
# Model_124 trained and saved to DAN_COMBINATIONS/model_layer124
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer125.
# Model_125 trained and saved to DAN_COMBINATIONS/model_layer125
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer126.
# Model_126 trained and saved to DAN_COMBINATIONS/model_layer126
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer127.
# Model_127 trained and saved to DAN_COMBINATIONS/model_layer127
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer128.
# Model_128 trained and saved to DAN_COMBINATIONS/model_layer128
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer129.
# Model_129 trained and saved to DAN_COMBINATIONS/model_layer129
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer130.
# Model_130 trained and saved to DAN_COMBINATIONS/model_layer130
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer131.
# Model_131 trained and saved to DAN_COMBINATIONS/model_layer131
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer132.
# Model_132 trained and saved to DAN_COMBINATIONS/model_layer132
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer133.
# Model_133 trained and saved to DAN_COMBINATIONS/model_layer133
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer134.
# Model_134 trained and saved to DAN_COMBINATIONS/model_layer134
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer135.
# Model_135 trained and saved to DAN_COMBINATIONS/model_layer135
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer136.
# Model_136 trained and saved to DAN_COMBINATIONS/model_layer136
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer137.
# Model_137 trained and saved to DAN_COMBINATIONS/model_layer137
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer138.
# Model_138 trained and saved to DAN_COMBINATIONS/model_layer138
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer139.
# Model_139 trained and saved to DAN_COMBINATIONS/model_layer139
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer140.
# Model_140 trained and saved to DAN_COMBINATIONS/model_layer140
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer141.
# Model_141 trained and saved to DAN_COMBINATIONS/model_layer141
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer142.
# Model_142 trained and saved to DAN_COMBINATIONS/model_layer142
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer143.
# Model_143 trained and saved to DAN_COMBINATIONS/model_layer143
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer144.
# Model_144 trained and saved to DAN_COMBINATIONS/model_layer144
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer145.
# Model_145 trained and saved to DAN_COMBINATIONS/model_layer145
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer146.
# Model_146 trained and saved to DAN_COMBINATIONS/model_layer146
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer147.
# Model_147 trained and saved to DAN_COMBINATIONS/model_layer147
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer148.
# Model_148 trained and saved to DAN_COMBINATIONS/model_layer148
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer149.
# Model_149 trained and saved to DAN_COMBINATIONS/model_layer149
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer150.
# Model_150 trained and saved to DAN_COMBINATIONS/model_layer150
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer151.
# Model_151 trained and saved to DAN_COMBINATIONS/model_layer151
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer152.
# Model_152 trained and saved to DAN_COMBINATIONS/model_layer152
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer153.
# Model_153 trained and saved to DAN_COMBINATIONS/model_layer153
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer154.
# Model_154 trained and saved to DAN_COMBINATIONS/model_layer154
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer155.
# Model_155 trained and saved to DAN_COMBINATIONS/model_layer155
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer156.
# Model_156 trained and saved to DAN_COMBINATIONS/model_layer156
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer157.
# Model_157 trained and saved to DAN_COMBINATIONS/model_layer157
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer158.
# Model_158 trained and saved to DAN_COMBINATIONS/model_layer158
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer159.
# Model_159 trained and saved to DAN_COMBINATIONS/model_layer159
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer160.
# Model_160 trained and saved to DAN_COMBINATIONS/model_layer160
# Model saved to /Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer161.
# Model_161 trained and saved to DAN_COMBINATIONS/model_layer161
# CPU times: user 12h 1s, sys: 1h 46min 1s, total: 13h 46min 3s
# Wall time: 7h 15min 15s

# %% [markdown]
# ## Running other Evaluation Tasks

# %%
# %run Eval_DAN_2.ipynb
# Out:
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer127/DAN_127', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '6', 'time': '1.7953984538714092', 'insampling_linear_kernel': 0.6484765802637562, 'test_linear_kernel': 0.6753069577080492, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.5402455661664393, 'test_rbf_kernel': 0.572987721691678, 'valid_score_rbf_kernel': 0.38333333333333336}
# 1 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer118/DAN_118', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '6', 'time': '1.6404570817947388', 'insampling_linear_kernel': 0.6160375928452326, 'test_linear_kernel': 0.6152796725784447, 'valid_score_linear_kernel': 0.38333333333333336, 'insampling_rbf_kernel': 0.4342883128694861, 'test_rbf_kernel': 0.44747612551159616, 'valid_score_rbf_kernel': 0.38333333333333336}
# 2 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer111/DAN_111', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '6', 'time': '3.269410498936971', 'insampling_linear_kernel': 0.6446869789298166, 'test_linear_kernel': 0.6248294679399727, 'valid_score_linear_kernel': 0.43333333333333335, 'insampling_rbf_kernel': 0.4677883886615128, 'test_rbf_kernel': 0.45702592087312416, 'valid_score_rbf_kernel': 0.35}
# 3 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer7/DAN_7', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '5.411894218126933', 'insampling_linear_kernel': 0.683037744429286, 'test_linear_kernel': 0.7025920873124147, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.5984538426557526, 'test_rbf_kernel': 0.6098226466575716, 'valid_score_rbf_kernel': 0.5166666666666667}
# 4 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer0/DAN_0', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '1.6773902455965677', 'insampling_linear_kernel': 0.6930422919508867, 'test_linear_kernel': 0.6903137789904502, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.6399878732757314, 'test_rbf_kernel': 0.626193724420191, 'valid_score_rbf_kernel': 0.48333333333333334}
# 5 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer116/DAN_116', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '6', 'time': '6.4957381844520565', 'insampling_linear_kernel': 0.5919357283613764, 'test_linear_kernel': 0.5907230559345157, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.43762316204335305, 'test_rbf_kernel': 0.4038199181446112, 'valid_score_rbf_kernel': 0.45}
# 6 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer129/DAN_129', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '6', 'time': '3.7095254182815554', 'insampling_linear_kernel': 0.5942094891617402, 'test_linear_kernel': 0.6030013642564802, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.43080187964226163, 'test_rbf_kernel': 0.43519781718963163, 'valid_score_rbf_kernel': 0.4166666666666667}
# 7 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer144/DAN_144', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '7', 'time': '1.7236690163612365', 'insampling_linear_kernel': 0.6164923450053055, 'test_linear_kernel': 0.5798090040927695, 'valid_score_linear_kernel': 0.4166666666666667, 'insampling_rbf_kernel': 0.5064423222676975, 'test_rbf_kernel': 0.4693042291950887, 'valid_score_rbf_kernel': 0.36666666666666664}
# 8 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer143/DAN_143', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '7', 'time': '6.818774700164795', 'insampling_linear_kernel': 0.49855995149310295, 'test_linear_kernel': 0.514324693042292, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.4047294224647567, 'test_rbf_kernel': 0.3942701227830832, 'valid_score_rbf_kernel': 0.4}
# 9 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer117/DAN_117', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '6', 'time': '1.67902059952418', 'insampling_linear_kernel': 0.5989085948158254, 'test_linear_kernel': 0.5839017735334243, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.46399878732757316, 'test_rbf_kernel': 0.504774897680764, 'valid_score_rbf_kernel': 0.4}
# 10 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer1/DAN_1', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '1.4995181202888488', 'insampling_linear_kernel': 0.690010610883735, 'test_linear_kernel': 0.684856753069577, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.6281643171138396, 'test_rbf_kernel': 0.6234652114597544, 'valid_score_rbf_kernel': 0.5333333333333333}
# 11 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer128/DAN_128', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '6', 'time': '1.8216210007667542', 'insampling_linear_kernel': 0.6307412460209186, 'test_linear_kernel': 0.6371077762619373, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.5099287554949219, 'test_rbf_kernel': 0.5075034106412005, 'valid_score_rbf_kernel': 0.5166666666666667}
# 12 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer6/DAN_6', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '5.7653215805689495', 'insampling_linear_kernel': 0.6821282401091405, 'test_linear_kernel': 0.6862210095497954, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.6128543277247234, 'test_rbf_kernel': 0.616643929058663, 'valid_score_rbf_kernel': 0.55}
# 13 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer110/DAN_110', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '6', 'time': '1.6573362270991008', 'insampling_linear_kernel': 0.6498408367439745, 'test_linear_kernel': 0.6330150068212824, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.5108382598150675, 'test_rbf_kernel': 0.5211459754433834, 'valid_score_rbf_kernel': 0.4}
# 14 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer126/DAN_126', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '6', 'time': '1.8072424054145813', 'insampling_linear_kernel': 0.6465059875701076, 'test_linear_kernel': 0.6466575716234653, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.4885554039715022, 'test_rbf_kernel': 0.4679399727148704, 'valid_score_rbf_kernel': 0.43333333333333335}
# 15 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer119/DAN_119', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '6', 'time': '1.6098524332046509', 'insampling_linear_kernel': 0.664696073973018, 'test_linear_kernel': 0.6521145975443383, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.5397908140063665, 'test_rbf_kernel': 0.5538881309686221, 'valid_score_rbf_kernel': 0.45}
# 16 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer121/DAN_121', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '6', 'time': '3.282500465710958', 'insampling_linear_kernel': 0.5552523874488404, 'test_linear_kernel': 0.5416098226466576, 'valid_score_linear_kernel': 0.4166666666666667, 'insampling_rbf_kernel': 0.43610732150977716, 'test_rbf_kernel': 0.4542974079126876, 'valid_score_rbf_kernel': 0.36666666666666664}
# 17 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer8/DAN_8', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '5.373146200180054', 'insampling_linear_kernel': 0.6878884341367288, 'test_linear_kernel': 0.6971350613915416, 'valid_score_linear_kernel': 0.5833333333333334, 'insampling_rbf_kernel': 0.6348340154615735, 'test_rbf_kernel': 0.654843110504775, 'valid_score_rbf_kernel': 0.5333333333333333}
# 18 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer103/DAN_103', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '5', 'time': '3.532740851243337', 'insampling_linear_kernel': 0.6566621191450659, 'test_linear_kernel': 0.6766712141882674, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.5076549946945581, 'test_rbf_kernel': 0.5156889495225102, 'valid_score_rbf_kernel': 0.5333333333333333}
# 19 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer104/DAN_104', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '5', 'time': '3.497515384356181', 'insampling_linear_kernel': 0.6412005457025921, 'test_linear_kernel': 0.6493860845839018, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.4929513415188722, 'test_rbf_kernel': 0.4870395634379263, 'valid_score_rbf_kernel': 0.4}
# 20 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer132/DAN_132', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '6', 'time': '8.130176432927449', 'insampling_linear_kernel': 0.5199333030165226, 'test_linear_kernel': 0.5266030013642565, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.39245111414279216, 'test_rbf_kernel': 0.39017735334242837, 'valid_score_rbf_kernel': 0.36666666666666664}
# 21 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer135/DAN_135', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '7', 'time': '1.7583521485328675', 'insampling_linear_kernel': 0.6339245111414279, 'test_linear_kernel': 0.6534788540245566, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.4564195846596938, 'test_rbf_kernel': 0.4529331514324693, 'valid_score_rbf_kernel': 0.38333333333333336}
# 22 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer161/DAN_161', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '7', 'time': '7.476575326919556', 'insampling_linear_kernel': 0.46733363650144005, 'test_linear_kernel': 0.4406548431105048, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.4077611035319084, 'test_rbf_kernel': 0.3956343792633015, 'valid_score_rbf_kernel': 0.4666666666666667}
# 23 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer159/DAN_159', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '7', 'time': '7.415136567751566', 'insampling_linear_kernel': 0.42913445505532816, 'test_linear_kernel': 0.42155525238744884, 'valid_score_linear_kernel': 0.38333333333333336, 'insampling_rbf_kernel': 0.40048506897074426, 'test_rbf_kernel': 0.40654843110504774, 'valid_score_rbf_kernel': 0.3333333333333333}
# 24 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer150/DAN_150', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '7', 'time': '6.7032030860582985', 'insampling_linear_kernel': 0.4509625587388207, 'test_linear_kernel': 0.44201909959072305, 'valid_score_linear_kernel': 0.38333333333333336, 'insampling_rbf_kernel': 0.4356525693497044, 'test_rbf_kernel': 0.43383356070941337, 'valid_score_rbf_kernel': 0.35}
# 25 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer157/DAN_157', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '7', 'time': '3.741158962249756', 'insampling_linear_kernel': 0.555403971502198, 'test_linear_kernel': 0.557980900409277, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.4230710929210247, 'test_rbf_kernel': 0.4229195088676671, 'valid_score_rbf_kernel': 0.38333333333333336}
# 26 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer134/DAN_134', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '6', 'time': '7.156868465741476', 'insampling_linear_kernel': 0.5899651356677278, 'test_linear_kernel': 0.5757162346521146, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.4157950583598605, 'test_rbf_kernel': 0.41882673942701226, 'valid_score_rbf_kernel': 0.36666666666666664}
# 27 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer133/DAN_133', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '6', 'time': '7.50067876180013', 'insampling_linear_kernel': 0.5910262240412308, 'test_linear_kernel': 0.5661664392905866, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.447172957404881, 'test_rbf_kernel': 0.4311050477489768, 'valid_score_rbf_kernel': 0.38333333333333336}
# 28 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer105/DAN_105', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '5', 'time': '7.065557797749837', 'insampling_linear_kernel': 0.6233136274063968, 'test_linear_kernel': 0.6152796725784447, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.4324693042291951, 'test_rbf_kernel': 0.42155525238744884, 'valid_score_rbf_kernel': 0.4}
# 29 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer102/DAN_102', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '5', 'time': '3.4410481174786884', 'insampling_linear_kernel': 0.6501440048506897, 'test_linear_kernel': 0.6221009549795361, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.5361527967257844, 'test_rbf_kernel': 0.5252387448840382, 'valid_score_rbf_kernel': 0.45}
# 30 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer156/DAN_156', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '7', 'time': '3.758382733662923', 'insampling_linear_kernel': 0.5405487342731544, 'test_linear_kernel': 0.5375170532060027, 'valid_score_linear_kernel': 0.4166666666666667, 'insampling_rbf_kernel': 0.4191299075337275, 'test_rbf_kernel': 0.4256480218281037, 'valid_score_rbf_kernel': 0.35}
# 31 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer151/DAN_151', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '7', 'time': '6.708350614706675', 'insampling_linear_kernel': 0.4439896922843717, 'test_linear_kernel': 0.42701227830832195, 'valid_score_linear_kernel': 0.43333333333333335, 'insampling_rbf_kernel': 0.4250416856146733, 'test_rbf_kernel': 0.40791268758526605, 'valid_score_rbf_kernel': 0.4666666666666667}
# 32 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer158/DAN_158', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '7', 'time': '3.7415053486824035', 'insampling_linear_kernel': 0.5262998332575413, 'test_linear_kernel': 0.5102319236016372, 'valid_score_linear_kernel': 0.38333333333333336, 'insampling_rbf_kernel': 0.41670456268000605, 'test_rbf_kernel': 0.3888130968622101, 'valid_score_rbf_kernel': 0.36666666666666664}
# 33 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer160/DAN_160', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '7', 'time': '7.446267584959666', 'insampling_linear_kernel': 0.44914355009852963, 'test_linear_kernel': 0.4379263301500682, 'valid_score_linear_kernel': 0.4166666666666667, 'insampling_rbf_kernel': 0.3888130968622101, 'test_rbf_kernel': 0.3587994542974079, 'valid_score_rbf_kernel': 0.3333333333333333}
# 34 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer20/DAN_20', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '1.7773176829020183', 'insampling_linear_kernel': 0.6847051690162195, 'test_linear_kernel': 0.7080491132332879, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.6377141124753676, 'test_rbf_kernel': 0.645293315143247, 'valid_score_rbf_kernel': 0.43333333333333335}
# 35 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer18/DAN_18', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '1.8472254157066346', 'insampling_linear_kernel': 0.6803092314688495, 'test_linear_kernel': 0.6834924965893588, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.6255873882067606, 'test_rbf_kernel': 0.6125511596180082, 'valid_score_rbf_kernel': 0.5333333333333333}
# 36 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer27/DAN_27', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '3', 'time': '1.5840614040692647', 'insampling_linear_kernel': 0.6656055782931636, 'test_linear_kernel': 0.6630286493860846, 'valid_score_linear_kernel': 0.5833333333333334, 'insampling_rbf_kernel': 0.5798090040927695, 'test_rbf_kernel': 0.5784447476125512, 'valid_score_rbf_kernel': 0.4666666666666667}
# 37 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer11/DAN_11', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '2', 'time': '1.361721134185791', 'insampling_linear_kernel': 0.6797028952554192, 'test_linear_kernel': 0.6780354706684857, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.6246778838866152, 'test_rbf_kernel': 0.607094133697135, 'valid_score_rbf_kernel': 0.5166666666666667}
# 38 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer29/DAN_29', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '3', 'time': '1.720639963944753', 'insampling_linear_kernel': 0.6778838866151281, 'test_linear_kernel': 0.6534788540245566, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.605275125056844, 'test_rbf_kernel': 0.6016371077762619, 'valid_score_rbf_kernel': 0.48333333333333334}
# 39 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer16/DAN_16', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '2', 'time': '6.290093831221262', 'insampling_linear_kernel': 0.6941033803243899, 'test_linear_kernel': 0.6834924965893588, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.6330150068212824, 'test_rbf_kernel': 0.6275579809004093, 'valid_score_rbf_kernel': 0.5166666666666667}
# 40 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer42/DAN_42', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '6.650704248746236', 'insampling_linear_kernel': 0.6690920115203881, 'test_linear_kernel': 0.7107776261937244, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.5673791117174474, 'test_rbf_kernel': 0.6098226466575716, 'valid_score_rbf_kernel': 0.55}
# 41 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer89/DAN_89', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '6.266531733671824', 'insampling_linear_kernel': 0.6639381537062301, 'test_linear_kernel': 0.6780354706684857, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.48931332423829016, 'test_rbf_kernel': 0.4693042291950887, 'valid_score_rbf_kernel': 0.4}
# 42 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer45/DAN_45', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '3', 'time': '1.5754228512446085', 'insampling_linear_kernel': 0.6865241776565105, 'test_linear_kernel': 0.6589358799454298, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.6304380779142035, 'test_rbf_kernel': 0.6180081855388813, 'valid_score_rbf_kernel': 0.55}
# 43 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer87/DAN_87', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '6.316464749972026', 'insampling_linear_kernel': 0.5986054267091102, 'test_linear_kernel': 0.597544338335607, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.43883583447021374, 'test_rbf_kernel': 0.417462482946794, 'valid_score_rbf_kernel': 0.4}
# 44 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer73/DAN_73', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '1.6501649657885233', 'insampling_linear_kernel': 0.6472639078368956, 'test_linear_kernel': 0.6534788540245566, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.570410792784599, 'test_rbf_kernel': 0.567530695770805, 'valid_score_rbf_kernel': 0.48333333333333334}
# 45 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer74/DAN_74', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '1.6794497172037761', 'insampling_linear_kernel': 0.6750037896013339, 'test_linear_kernel': 0.6343792633015006, 'valid_score_linear_kernel': 0.4166666666666667, 'insampling_rbf_kernel': 0.5937547370016675, 'test_rbf_kernel': 0.5757162346521146, 'valid_score_rbf_kernel': 0.45}
# 46 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer80/DAN_80', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '6.60575266679128', 'insampling_linear_kernel': 0.6631802334394422, 'test_linear_kernel': 0.6766712141882674, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.538123389419433, 'test_rbf_kernel': 0.5457025920873124, 'valid_score_rbf_kernel': 0.5}
# 47 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer28/DAN_28', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '3', 'time': '1.6872414151827495', 'insampling_linear_kernel': 0.6637865696528725, 'test_linear_kernel': 0.6821282401091405, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.593906321055025, 'test_rbf_kernel': 0.6030013642564802, 'valid_score_rbf_kernel': 0.48333333333333334}
# 48 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer17/DAN_17', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '2', 'time': '6.149337418874105', 'insampling_linear_kernel': 0.6930422919508867, 'test_linear_kernel': 0.6671214188267395, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.6390783689555859, 'test_rbf_kernel': 0.6016371077762619, 'valid_score_rbf_kernel': 0.5333333333333333}
# 49 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer10/DAN_10', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '2', 'time': '1.326082952817281', 'insampling_linear_kernel': 0.7001667424586934, 'test_linear_kernel': 0.6862210095497954, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.6519630134909807, 'test_rbf_kernel': 0.6289222373806276, 'valid_score_rbf_kernel': 0.5}
# 50 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer19/DAN_19', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '1.8710151632626852', 'insampling_linear_kernel': 0.6884947703501592, 'test_linear_kernel': 0.6984993178717599, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.6302864938608458, 'test_rbf_kernel': 0.635743519781719, 'valid_score_rbf_kernel': 0.48333333333333334}
# 51 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer26/DAN_26', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '8.688285601139068', 'insampling_linear_kernel': 0.6850083371229346, 'test_linear_kernel': 0.6834924965893588, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.6384720327421555, 'test_rbf_kernel': 0.6193724420190996, 'valid_score_rbf_kernel': 0.5}
# 52 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer21/DAN_21', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '3.5291150848070783', 'insampling_linear_kernel': 0.6889495225102319, 'test_linear_kernel': 0.6753069577080492, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.6319539184477793, 'test_rbf_kernel': 0.6343792633015006, 'valid_score_rbf_kernel': 0.5}
# 53 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer81/DAN_81', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '1.5669073661168416', 'insampling_linear_kernel': 0.6616643929058663, 'test_linear_kernel': 0.6875852660300137, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.5482795209943914, 'test_rbf_kernel': 0.5607094133697135, 'valid_score_rbf_kernel': 0.5166666666666667}
# 54 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer75/DAN_75', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '3.3507622122764587', 'insampling_linear_kernel': 0.662877065332727, 'test_linear_kernel': 0.654843110504775, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.49643777474609674, 'test_rbf_kernel': 0.4924965893587995, 'valid_score_rbf_kernel': 0.36666666666666664}
# 55 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer72/DAN_72', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '1.6191519856452943', 'insampling_linear_kernel': 0.6784902228285584, 'test_linear_kernel': 0.6589358799454298, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.5629831741700773, 'test_rbf_kernel': 0.5552523874488404, 'valid_score_rbf_kernel': 0.5166666666666667}
# 56 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer86/DAN_86', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '3.1456459124883014', 'insampling_linear_kernel': 0.6216462028194634, 'test_linear_kernel': 0.5961800818553888, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.45929968167348795, 'test_rbf_kernel': 0.4461118690313779, 'valid_score_rbf_kernel': 0.4666666666666667}
# 57 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer44/DAN_44', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '5.6648120284080505', 'insampling_linear_kernel': 0.6813703198423526, 'test_linear_kernel': 0.6534788540245566, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.5934515688949522, 'test_rbf_kernel': 0.5620736698499318, 'valid_score_rbf_kernel': 0.43333333333333335}
# 58 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer43/DAN_43', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '7.37763991355896', 'insampling_linear_kernel': 0.6645444899196604, 'test_linear_kernel': 0.669849931787176, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.5613157495831439, 'test_rbf_kernel': 0.5648021828103683, 'valid_score_rbf_kernel': 0.48333333333333334}
# 59 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer88/DAN_88', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '6.196635349591573', 'insampling_linear_kernel': 0.580718508412915, 'test_linear_kernel': 0.5893587994542974, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.4001819008640291, 'test_rbf_kernel': 0.4201909959072306, 'valid_score_rbf_kernel': 0.38333333333333336}
# 60 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer38/DAN_38', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '2.0389618992805483', 'insampling_linear_kernel': 0.6912232833105957, 'test_linear_kernel': 0.6957708049113234, 'valid_score_linear_kernel': 0.5833333333333334, 'insampling_rbf_kernel': 0.62877065332727, 'test_rbf_kernel': 0.6466575716234653, 'valid_score_rbf_kernel': 0.5166666666666667}
# 61 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer36/DAN_36', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '1.7476890961329141', 'insampling_linear_kernel': 0.6869789298165833, 'test_linear_kernel': 0.6875852660300137, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.6102773988176444, 'test_rbf_kernel': 0.5757162346521146, 'valid_score_rbf_kernel': 0.5166666666666667}
# 62 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer31/DAN_31', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '3', 'time': '3.394905451933543', 'insampling_linear_kernel': 0.6809155676822798, 'test_linear_kernel': 0.6562073669849932, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.5848112778535698, 'test_rbf_kernel': 0.557980900409277, 'valid_score_rbf_kernel': 0.5166666666666667}
# 63 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer65/DAN_65', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '4', 'time': '1.438001235326131', 'insampling_linear_kernel': 0.6772775504016978, 'test_linear_kernel': 0.6739427012278308, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.5857207821737154, 'test_rbf_kernel': 0.5470668485675307, 'valid_score_rbf_kernel': 0.43333333333333335}
# 64 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer91/DAN_91', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '5', 'time': '1.5400022188822429', 'insampling_linear_kernel': 0.6580263756252842, 'test_linear_kernel': 0.6575716234652115, 'valid_score_linear_kernel': 0.43333333333333335, 'insampling_rbf_kernel': 0.544035167500379, 'test_rbf_kernel': 0.557980900409277, 'valid_score_rbf_kernel': 0.45}
# 65 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer96/DAN_96', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '5', 'time': '6.115267451604208', 'insampling_linear_kernel': 0.5272093375776868, 'test_linear_kernel': 0.5061391541609823, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.41822040321358195, 'test_rbf_kernel': 0.3819918144611187, 'valid_score_rbf_kernel': 0.4}
# 66 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer62/DAN_62', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '4', 'time': '5.828535115718841', 'insampling_linear_kernel': 0.658481127785357, 'test_linear_kernel': 0.6766712141882674, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.5264514173108988, 'test_rbf_kernel': 0.5402455661664393, 'valid_score_rbf_kernel': 0.4166666666666667}
# 67 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer54/DAN_54', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '4', 'time': '1.4754220008850099', 'insampling_linear_kernel': 0.6657571623465212, 'test_linear_kernel': 0.6821282401091405, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.5581324844626345, 'test_rbf_kernel': 0.5798090040927695, 'valid_score_rbf_kernel': 0.45}
# 68 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer98/DAN_98', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '5', 'time': '6.0546477198600765', 'insampling_linear_kernel': 0.6327118387145673, 'test_linear_kernel': 0.6234652114597544, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.49007124450507805, 'test_rbf_kernel': 0.4843110504774898, 'valid_score_rbf_kernel': 0.45}
# 69 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer53/DAN_53', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '3', 'time': '6.470392966270447', 'insampling_linear_kernel': 0.6922843716840988, 'test_linear_kernel': 0.6534788540245566, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.6113384871911475, 'test_rbf_kernel': 0.5743519781718963, 'valid_score_rbf_kernel': 0.5}
# 70 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer30/DAN_30', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '3', 'time': '3.4435192346572876', 'insampling_linear_kernel': 0.6818250720024254, 'test_linear_kernel': 0.6930422919508867, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.5725329695316053, 'test_rbf_kernel': 0.5811732605729877, 'valid_score_rbf_kernel': 0.38333333333333336}
# 71 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer37/DAN_37', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '1.8172647515932718', 'insampling_linear_kernel': 0.6880400181900864, 'test_linear_kernel': 0.669849931787176, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.6469607397301804, 'test_rbf_kernel': 0.6384720327421555, 'valid_score_rbf_kernel': 0.55}
# 72 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer39/DAN_39', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '3.374780837694804', 'insampling_linear_kernel': 0.6777323025617705, 'test_linear_kernel': 0.6971350613915416, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.5995149310292557, 'test_rbf_kernel': 0.6016371077762619, 'valid_score_rbf_kernel': 0.45}
# 73 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer99/DAN_99', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '5', 'time': '1.7221157670021057', 'insampling_linear_kernel': 0.6631802334394422, 'test_linear_kernel': 0.6589358799454298, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.5996665150826133, 'test_rbf_kernel': 0.592087312414734, 'valid_score_rbf_kernel': 0.48333333333333334}
# 74 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer52/DAN_52', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '3', 'time': '6.753395346800486', 'insampling_linear_kernel': 0.6569652872517812, 'test_linear_kernel': 0.654843110504775, 'valid_score_linear_kernel': 0.5666666666666667, 'insampling_rbf_kernel': 0.5766257389722601, 'test_rbf_kernel': 0.5798090040927695, 'valid_score_rbf_kernel': 0.5333333333333333}
# 75 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer55/DAN_55', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '4', 'time': '1.4738239526748658', 'insampling_linear_kernel': 0.661058056692436, 'test_linear_kernel': 0.6684856753069577, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.5740488100651812, 'test_rbf_kernel': 0.5934515688949522, 'valid_score_rbf_kernel': 0.43333333333333335}
# 76 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer63/DAN_63', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '4', 'time': '1.434790297349294', 'insampling_linear_kernel': 0.6772775504016978, 'test_linear_kernel': 0.6753069577080492, 'valid_score_linear_kernel': 0.5833333333333334, 'insampling_rbf_kernel': 0.5840533575867819, 'test_rbf_kernel': 0.5593451568894953, 'valid_score_rbf_kernel': 0.5}
# 77 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer97/DAN_97', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '5', 'time': '6.0745412866274515', 'insampling_linear_kernel': 0.5329695316052752, 'test_linear_kernel': 0.5266030013642565, 'valid_score_linear_kernel': 0.4, 'insampling_rbf_kernel': 0.44686978929816584, 'test_rbf_kernel': 0.4201909959072306, 'valid_score_rbf_kernel': 0.4166666666666667}
# 78 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer90/DAN_90', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '5', 'time': '1.5332059542338052', 'insampling_linear_kernel': 0.6480218281036835, 'test_linear_kernel': 0.6862210095497954, 'valid_score_linear_kernel': 0.5666666666666667, 'insampling_rbf_kernel': 0.47658026375625284, 'test_rbf_kernel': 0.48567530695770805, 'valid_score_rbf_kernel': 0.45}
# 79 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer64/DAN_64', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '4', 'time': '1.43475501537323', 'insampling_linear_kernel': 0.6549946945581325, 'test_linear_kernel': 0.6643929058663028, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.5175079581628013, 'test_rbf_kernel': 0.5347885402455662, 'valid_score_rbf_kernel': 0.48333333333333334}
# 80 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer124/DAN_124', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '6', 'time': '6.453404386838277', 'insampling_linear_kernel': 0.5155373654691526, 'test_linear_kernel': 0.5429740791268759, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.4126117932393512, 'test_rbf_kernel': 0.43383356070941337, 'valid_score_rbf_kernel': 0.4166666666666667}
# 81 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer123/DAN_123', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '6', 'time': '6.316422768433889', 'insampling_linear_kernel': 0.49916628770653326, 'test_linear_kernel': 0.495225102319236, 'valid_score_linear_kernel': 0.4166666666666667, 'insampling_rbf_kernel': 0.4026072457177505, 'test_rbf_kernel': 0.39836289222373805, 'valid_score_rbf_kernel': 0.4}
# 82 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer3/DAN_3', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '3.0564319173494976', 'insampling_linear_kernel': 0.6906169470971654, 'test_linear_kernel': 0.6875852660300137, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.6268000606336214, 'test_rbf_kernel': 0.6466575716234653, 'valid_score_rbf_kernel': 0.5333333333333333}
# 83 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer115/DAN_115', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '6', 'time': '6.5912996133168535', 'insampling_linear_kernel': 0.5705623768379566, 'test_linear_kernel': 0.6016371077762619, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.44641503713809305, 'test_rbf_kernel': 0.43519781718963163, 'valid_score_rbf_kernel': 0.31666666666666665}
# 84 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer112/DAN_112', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '6', 'time': '3.3071670651435854', 'insampling_linear_kernel': 0.6095194785508564, 'test_linear_kernel': 0.6152796725784447, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.44671820524480826, 'test_rbf_kernel': 0.44474761255115963, 'valid_score_rbf_kernel': 0.48333333333333334}
# 85 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer4/DAN_4', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '3.031414182980855', 'insampling_linear_kernel': 0.6784902228285584, 'test_linear_kernel': 0.6575716234652115, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.6030013642564802, 'test_rbf_kernel': 0.6002728512960437, 'valid_score_rbf_kernel': 0.4666666666666667}
# 86 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer146/DAN_146', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '7', 'time': '1.699759833017985', 'insampling_linear_kernel': 0.6007276034561164, 'test_linear_kernel': 0.6302864938608458, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.4881006518114294, 'test_rbf_kernel': 0.4733969986357435, 'valid_score_rbf_kernel': 0.4166666666666667}
# 87 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer141/DAN_141', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '7', 'time': '6.7892641504605615', 'insampling_linear_kernel': 0.4899196604517205, 'test_linear_kernel': 0.49931787175989084, 'valid_score_linear_kernel': 0.4, 'insampling_rbf_kernel': 0.4368652417765651, 'test_rbf_kernel': 0.4529331514324693, 'valid_score_rbf_kernel': 0.36666666666666664}
# 88 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer148/DAN_148', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '7', 'time': '3.3701884865760805', 'insampling_linear_kernel': 0.55904198878278, 'test_linear_kernel': 0.5416098226466576, 'valid_score_linear_kernel': 0.4, 'insampling_rbf_kernel': 0.41336971350613916, 'test_rbf_kernel': 0.4256480218281037, 'valid_score_rbf_kernel': 0.35}
# 89 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer5/DAN_5', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '2.7756638526916504', 'insampling_linear_kernel': 0.6772775504016978, 'test_linear_kernel': 0.6712141882673943, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.6011823556161892, 'test_rbf_kernel': 0.5852660300136425, 'valid_score_rbf_kernel': 0.5166666666666667}
# 90 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer113/DAN_113', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '6', 'time': '3.2694583853085835', 'insampling_linear_kernel': 0.6398362892223738, 'test_linear_kernel': 0.6739427012278308, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.4691526451417311, 'test_rbf_kernel': 0.47885402455661663, 'valid_score_rbf_kernel': 0.43333333333333335}
# 91 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer114/DAN_114', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '6', 'time': '6.570617214838664', 'insampling_linear_kernel': 0.5760194027588298, 'test_linear_kernel': 0.5607094133697135, 'valid_score_linear_kernel': 0.38333333333333336, 'insampling_rbf_kernel': 0.4142792178262847, 'test_rbf_kernel': 0.3969986357435198, 'valid_score_rbf_kernel': 0.35}
# 92 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer2/DAN_2', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '2', 'time': '1.770320173104604', 'insampling_linear_kernel': 0.6927391238441716, 'test_linear_kernel': 0.6957708049113234, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.6324086706078521, 'test_rbf_kernel': 0.616643929058663, 'valid_score_rbf_kernel': 0.5333333333333333}
# 93 of 162
# ...
# 107 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer155/DAN_155', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '7', 'time': '1.8845237493515015', 'insampling_linear_kernel': 0.6049719569501288, 'test_linear_kernel': 0.5907230559345157, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.4849173866909201, 'test_rbf_kernel': 0.4924965893587995, 'valid_score_rbf_kernel': 0.36666666666666664}
# 108 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer130/DAN_130', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '6', 'time': '3.734576086203257', 'insampling_linear_kernel': 0.582537517053206, 'test_linear_kernel': 0.5620736698499318, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.4276186145217523, 'test_rbf_kernel': 0.41882673942701226, 'valid_score_rbf_kernel': 0.3333333333333333}
# 109 of 162
# {'epoches': '5', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer108/DAN_108', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '6', 'time': '1.64820663134257', 'insampling_linear_kernel': 0.6257389722601182, 'test_linear_kernel': 0.616643929058663, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.5150826133090799, 'test_rbf_kernel': 0.5129604365620737, 'valid_score_rbf_kernel': 0.45}
# 110 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer137/DAN_137', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '7', 'time': '1.7283983469009399', 'insampling_linear_kernel': 0.642716386236168, 'test_linear_kernel': 0.654843110504775, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.5390328937395786, 'test_rbf_kernel': 0.5497953615279673, 'valid_score_rbf_kernel': 0.48333333333333334}
# 111 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer101/DAN_101', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '5', 'time': '1.737625249226888', 'insampling_linear_kernel': 0.6556010307715628, 'test_linear_kernel': 0.6657571623465212, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.5196301349098075, 'test_rbf_kernel': 0.5129604365620737, 'valid_score_rbf_kernel': 0.4666666666666667}
# 112 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer139/DAN_139', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '7', 'time': '3.4138569831848145', 'insampling_linear_kernel': 0.5303926026981961, 'test_linear_kernel': 0.5170532060027285, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.4461118690313779, 'test_rbf_kernel': 0.4665757162346521, 'valid_score_rbf_kernel': 0.45}
# 113 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer106/DAN_106', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '5', 'time': '6.793939650058746', 'insampling_linear_kernel': 0.6089131423374261, 'test_linear_kernel': 0.5784447476125512, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.46627254812793695, 'test_rbf_kernel': 0.4665757162346521, 'valid_score_rbf_kernel': 0.35}
# 114 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer46/DAN_46', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '3', 'time': '1.6077768325805664', 'insampling_linear_kernel': 0.6772775504016978, 'test_linear_kernel': 0.6575716234652115, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.5970895861755343, 'test_rbf_kernel': 0.567530695770805, 'valid_score_rbf_kernel': 0.5166666666666667}
# 115 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer79/DAN_79', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '6.562858700752258', 'insampling_linear_kernel': 0.6416552978626648, 'test_linear_kernel': 0.6521145975443383, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.4552069122328331, 'test_rbf_kernel': 0.4406548431105048, 'valid_score_rbf_kernel': 0.4}
# 116 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer41/DAN_41', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '3.6346192359924316', 'insampling_linear_kernel': 0.680460815522207, 'test_linear_kernel': 0.679399727148704, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.593906321055025, 'test_rbf_kernel': 0.592087312414734, 'valid_score_rbf_kernel': 0.48333333333333334}
# 117 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer77/DAN_77', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '3.3319454352060953', 'insampling_linear_kernel': 0.6703046839472487, 'test_linear_kernel': 0.6493860845839018, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.5907230559345157, 'test_rbf_kernel': 0.5757162346521146, 'valid_score_rbf_kernel': 0.45}
# 118 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer83/DAN_83', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '1.5598647713661193', 'insampling_linear_kernel': 0.6595422161588601, 'test_linear_kernel': 0.6466575716234653, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.5490374412611794, 'test_rbf_kernel': 0.5552523874488404, 'valid_score_rbf_kernel': 0.4666666666666667}
# 119 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer48/DAN_48', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '3', 'time': '17.85421021779378', 'insampling_linear_kernel': 0.6807639836289222, 'test_linear_kernel': 0.6589358799454298, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.617401849325451, 'test_rbf_kernel': 0.6030013642564802, 'valid_score_rbf_kernel': 0.5}
# 120 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer84/DAN_84', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '3.0945106665293376', 'insampling_linear_kernel': 0.6310444141276338, 'test_linear_kernel': 0.6084583901773534, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.4723359102622404, 'test_rbf_kernel': 0.4747612551159618, 'valid_score_rbf_kernel': 0.36666666666666664}
# 121 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer70/DAN_70', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '4', 'time': '5.661544466018677', 'insampling_linear_kernel': 0.634227679248143, 'test_linear_kernel': 0.616643929058663, 'valid_score_linear_kernel': 0.4666666666666667, 'insampling_rbf_kernel': 0.47870244050325905, 'test_rbf_kernel': 0.4693042291950887, 'valid_score_rbf_kernel': 0.36666666666666664}
# 122 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer24/DAN_24', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '8.93255543311437', 'insampling_linear_kernel': 0.6912232833105957, 'test_linear_kernel': 0.6780354706684857, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.6361982719417917, 'test_rbf_kernel': 0.6248294679399727, 'valid_score_rbf_kernel': 0.5166666666666667}
# 123 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer23/DAN_23', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '4.1743728478749595', 'insampling_linear_kernel': 0.6906169470971654, 'test_linear_kernel': 0.6616643929058663, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.6439290586630286, 'test_rbf_kernel': 0.6207366984993179, 'valid_score_rbf_kernel': 0.4666666666666667}
# 124 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer15/DAN_15', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '2', 'time': '6.2024739503860475', 'insampling_linear_kernel': 0.6874336819766561, 'test_linear_kernel': 0.6971350613915416, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.6183113536455965, 'test_rbf_kernel': 0.6098226466575716, 'valid_score_rbf_kernel': 0.48333333333333334}
# 125 of 162
# {'epoches': '10', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer12/DAN_12', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '2', 'time': '2.700264835357666', 'insampling_linear_kernel': 0.685614673336365, 'test_linear_kernel': 0.6916780354706685, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.6502955889040473, 'test_rbf_kernel': 0.6575716234652115, 'valid_score_rbf_kernel': 0.5166666666666667}
# 126 of 162
# {'epoches': '20', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer71/DAN_71', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '4', 'time': '5.680684085687002', 'insampling_linear_kernel': 0.6615128088525087, 'test_linear_kernel': 0.6507503410641201, 'valid_score_linear_kernel': 0.5166666666666667, 'insampling_rbf_kernel': 0.5467636804608155, 'test_rbf_kernel': 0.5538881309686221, 'valid_score_rbf_kernel': 0.5333333333333333}
# 127 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer85/DAN_85', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '3.1226373354593915', 'insampling_linear_kernel': 0.6492345005305442, 'test_linear_kernel': 0.6098226466575716, 'valid_score_linear_kernel': 0.5833333333333334, 'insampling_rbf_kernel': 0.4370168258299227, 'test_rbf_kernel': 0.39154160982264663, 'valid_score_rbf_kernel': 0.36666666666666664}
# 128 of 162
# {'epoches': '5', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer82/DAN_82', 'classes': '3', 'classifier_shape': '[200]', 'hidden_layer': '5', 'time': '1.5796736478805542', 'insampling_linear_kernel': 0.6607548885857207, 'test_linear_kernel': 0.6630286493860846, 'valid_score_linear_kernel': 0.45, 'insampling_rbf_kernel': 0.509170835228134, 'test_rbf_kernel': 0.514324693042292, 'valid_score_rbf_kernel': 0.38333333333333336}
# 129 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer76/DAN_76', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '3.2486636797587076', 'insampling_linear_kernel': 0.6774291344550554, 'test_linear_kernel': 0.679399727148704, 'valid_score_linear_kernel': 0.5666666666666667, 'insampling_rbf_kernel': 0.5770804911323328, 'test_rbf_kernel': 0.5934515688949522, 'valid_score_rbf_kernel': 0.5166666666666667}
# 130 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer49/DAN_49', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '3', 'time': '3.463635035355886', 'insampling_linear_kernel': 0.6651508261330908, 'test_linear_kernel': 0.6562073669849932, 'valid_score_linear_kernel': 0.6, 'insampling_rbf_kernel': 0.5896619675610126, 'test_rbf_kernel': 0.5607094133697135, 'valid_score_rbf_kernel': 0.5}
# 131 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer40/DAN_40', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '3', 'time': '3.6136898199717202', 'insampling_linear_kernel': 0.6810671517356374, 'test_linear_kernel': 0.6807639836289222, 'valid_score_linear_kernel': 0.55, 'insampling_rbf_kernel': 0.6051235410034864, 'test_rbf_kernel': 0.6043656207366985, 'valid_score_rbf_kernel': 0.48333333333333334}
# 132 of 162
# {'epoches': '5', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer47/DAN_47', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '3', 'time': '5.466680717468262', 'insampling_linear_kernel': 0.6891011065635895, 'test_linear_kernel': 0.6916780354706685, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.6164923450053055, 'test_rbf_kernel': 0.6371077762619373, 'valid_score_rbf_kernel': 0.5166666666666667}
# 133 of 162
# {'epoches': '20', 'dropout': '0.2', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer78/DAN_78', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '4', 'time': '6.59145538409551', 'insampling_linear_kernel': 0.6439290586630286, 'test_linear_kernel': 0.6316507503410641, 'valid_score_linear_kernel': 0.5333333333333333, 'insampling_rbf_kernel': 0.48340154615734426, 'test_rbf_kernel': 0.4979536152796726, 'valid_score_rbf_kernel': 0.45}
# 134 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer13/DAN_13', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '2', 'time': '3.0643255869547525', 'insampling_linear_kernel': 0.672426860694255, 'test_linear_kernel': 0.7066848567530696, 'valid_score_linear_kernel': 0.5, 'insampling_rbf_kernel': 0.6198271941791723, 'test_rbf_kernel': 0.6398362892223738, 'valid_score_rbf_kernel': 0.5}
# 135 of 162
# {'epoches': '10', 'dropout': '0.5', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer14/DAN_14', 'classes': '3', 'classifier_shape': '[100, 50]', 'hidden_layer': '2', 'time': '3.0167625665664675', 'insampling_linear_kernel': 0.6965287251781113, 'test_linear_kernel': 0.6480218281036835, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.6455964832499621, 'test_rbf_kernel': 0.6084583901773534, 'valid_score_rbf_kernel': 0.5}
# 136 of 162
# {'epoches': '10', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer22/DAN_22', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '3.7184944709142047', 'insampling_linear_kernel': 0.6833409125360013, 'test_linear_kernel': 0.6971350613915416, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.6374109443686524, 'test_rbf_kernel': 0.6207366984993179, 'valid_score_rbf_kernel': 0.48333333333333334}
# 137 of 162
# {'epoches': '20', 'dropout': '0.3', 'path': '/Users/Daniel/PycharmProjects/Recommender-System/notebooks/DAN_COMBINATIONS/model_layer25/DAN_25', 'classes': '3', 'classifier_shape': '[200, 100]', 'hidden_layer': '2', 'time': '9.386969252427418', 'insampling_linear_kernel': 0.6840988328027892, 'test_linear_kernel': 0.6834924965893588, 'valid_score_linear_kernel': 0.48333333333333334, 'insampling_rbf_kernel': 0.6207366984993179, 'test_rbf_kernel': 0.6316507503410641, 'valid_score_rbf_kernel': 0.4666666666666667}
# 138 of 162

# %%
# %matplotlib
# %run Eval_DAN_3.ipynb
# Out:
# Using matplotlib backend: TkAgg
